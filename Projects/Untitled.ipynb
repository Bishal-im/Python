# %%
#Available in docs
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
 
url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'          # https://pro-api.coinmarketcap.com  (get this in Authenction part) 
parameters = {
  'start':'1',
  'limit':'15',             # for ease you can set limit of data you want as (default set is 5000) 
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': 'abcdd7dd1d194f699a3d87d855c40015',  # insert your APi Key
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)


# error may occur so Increase the data rate limit    (jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10)
# Out:
# {'status': {'timestamp': '2025-11-06T16:34:40.881Z', 'error_code': 0, 'error_message': None, 'elapsed': 40, 'credit_count': 1, 'notice': None, 'total_count': 9313}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 12468, 'date_added': '2010-07-13T00:00:00.000Z', 'tags': ['mineable', 'pow', 'sha-256', 'store-of-value', 'state-channel', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'galaxy-digital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'bitcoin-ecosystem', 'layer-1', 'ftx-bankruptcy-estate', '2017-2018-alt-season', 'us-strategic-crypto-reserve', 'binance-ecosystem', 'binance-listing'], 'max_supply': 21000000, 'circulating_supply': 19945262, 'total_supply': 19945262, 'infinite_supply': False, 'platform': None, 'cmc_rank': 1, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2025-11-06T16:33:00.000Z', 'quote': {'USD': {'price': 101482.45832834466, 'volume_24h': 58870031367.87058, 'volume_change_24h': -45.046, 'percent_change_1h': -0.80379054, 'percent_change_24h': -2.02129462, 'percent_change_7d': -6.0872371, 'percent_change_30d': -16.50989345, 'percent_change_60d': -8.74959784, 'percent_change_90d': -12.58503893, 'market_cap': 2024094219762.9163, 'market_cap_dominance': 59.9783, 'fully_diluted_market_cap': 2131131624895.24, 'tvl': None, 'last_updated': '2025-11-06T16:33:00.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 11100, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['pos', 'smart-contracts', 'ethereum-ecosystem', 'coinbase-ventures-portfolio', 'three-arrows-capital-portfolio', 'polychain-capital-portfolio', 'binance-labs-portfolio', 'blockchain-capital-portfolio', 'boostvc-portfolio', 'cms-holdings-portfolio', 'dcg-portfolio', 'dragonfly-capital-portfolio', 'electric-capital-portfolio', 'fabric-ventures-portfolio', 'framework-ventures-portfolio', 'hashkey-capital-portfolio', 'kenetic-capital-portfolio', 'huobi-capital-portfolio', 'alameda-research-portfolio', 'a16z-portfolio', '1confirmation-portfolio', 'winklevoss-capital-portfolio', 'usv-portfolio', 'placeholder-ventures-portfolio', 'pantera-capital-portfolio', 'multicoin-capital-portfolio', 'paradigm-portfolio', 'ethereum-pow-ecosystem', 'layer-1', 'ftx-bankruptcy-estate', 'sora-ecosystem', 'rsk-rbtc-ecosystem', 'world-liberty-financial-portfolio', 'us-strategic-crypto-reserve', 'binance-ecosystem', 'binance-listing', 'sophon-ecosystem'], 'max_supply': None, 'circulating_supply': 120697167.1614941, 'total_supply': 120697167.1614941, 'infinite_supply': True, 'platform': None, 'cmc_rank': 2, 'self_reported_circulating_supply': None, 'self_reported_market_cap': None, 'tvl_ratio': None, 'last_updated': '2025-11-06T16:33:00.000Z', 'quote': {'USD': {'price': 3290.773774437974, 'volume_24h': 36268858819.218636, 'volume_change_24h': -48.9725, 'percent_change_1h': -1.41714985, 'percent_change_24h': -3.00587717, 'percent_change_7d': -13.23842258, 'percent_change_30d': -26.829057, 'percent_change_60d': -23.29498985, 'percent_change_90d': -16.97959669, 'market_cap': 397187072344.0011, 'market_cap_dominance': 11.7791, 'fully_diluted_market_cap': 397187072344, 'tvl': None, 'last_updated': '2025-11-06T16:33:00.000Z'}}}, {'id': 825, 'name': 'Tether USDt', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 157087, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': ['stablecoin', 'asset-backed-stable ...

# %%
type(data)
# Out:
# dict

# %%
#normalize json and max the column
import pandas as pd 

pd.set_option('display.max_columns' ,None)
pd.set_option('display.max_rows' ,None)

# %%
df = pd.json_normalize(data['data'])     # var[data]
df['timestamp'] = pd.to_datetime('now')   # creating and adding timestamp column 

df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             12468
# 1    1027      Ethereum    ETH      ethereum             11100
# 2     825   Tether USDt   USDT        tether            157087
# 3      52           XRP    XRP           xrp              1754
# 4    1839           BNB    BNB           bnb              2934
# 5    5426        Solana    SOL        solana              1046
# 6    3408          USDC   USDC      usd-coin             34159
# 7    1958          TRON    TRX          tron              1259
# 8      74      Dogecoin   DOGE      dogecoin              1345
# 9    2010       Cardano    ADA       cardano              1621
# 10  32196   Hyperliquid   HYPE   hyperliquid               195
# 11   1975     Chainlink   LINK     chainlink              2143
# 12   1831  Bitcoin Cash    BCH  bitcoin-cash              1091
# 13  29470   Ethena USDe   USDe   ethena-usde               242
# 14   3957  UNUS SED LEO    LEO  unus-sed-leo                64
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2013-08-04T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2020-04-10T00:00:00.000Z
# 6   2018-10-08T00:00:00.000Z
# 7   2017-09-13T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2017-10-01T00:00:00.000Z
# 10  2024-07-15T10:14:50.000Z
# 11  2017-09-20T00:00:00.000Z
# 12  2017-07-23T00:00:00.000Z
# 13  2024-02-20T11:05:01.000Z
# 14  2019-05-21T00:00:00.000Z
#
#                                                  tags    max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...  2.100000e+07
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...           NaN
# 2   [stablecoin, asset-backed-stablecoin, usd-stab...           NaN
# 3   [medium-of-exchange, enterprise-solutions, xrp...  1.000000e+11
# 4   [marketplace, centralized-exchange, payments, ...  1.377375e+08
# 5   [pos, platform, solana-ecosystem, cms-holdings...           NaN
# 6   [medium-of-exchange, stablecoin, asset-backed-...           NaN
# 7   [media, payments, tron-ecosystem, layer-1, dwf...           NaN
# 8   [mineable, pow, scrypt, medium-of-exchange, me...           NaN
# 9   [dpos, pos, platform, research, smart-contract...  4.500000e+10
# 10  [decentralized-exchange-dex-token, defi, deriv...  9.995333e+08
# 11  [platform, cosmos-ecosystem, defi, interoperab...  1.000000e+09
# 12  [mineable, pow, sha-256, marketplace, medium-o...  2.100000e+07
# 13  [stablecoin, asset-backed-stablecoin, binance-...           NaN
# 14  [marketplace, centralized-exchange, discount-t...           NaN
#
#     circulating_supply  total_supply  infinite_supply  platform  cmc_rank  \
# 0         1.994526e+07  1.994526e+07            False       NaN         1
# 1         1.206972e+08  1.206972e+08             True       NaN         2
# 2         1.834592e+11  1.859512e+11             True       NaN         3
# 3         6.010720e+10  9.998577e+10            False       NaN         4
# 4         1.377375e+08  1.377375e+08            False       NaN         5
# 5         5.527395e+08  6.134047e+08             True       NaN         6
# 6         7.509119e+10  7.509119e+10            False       NaN         7
# 7         9.466575e+10  9.466576e+10             True       NaN         8
# 8         1.516623e+11  1.516623e+11             True       NaN         9
# 9         3.586628e+10  4.499457e+10            False       NaN        10
# 10        3.366852e+08  9.995333e+08            False       NaN        11
# 11        6.968500e+08  1.000000e+09            False       NaN        12
# 12        1.994930e+07  1.994930e+07            False       NaN        13
# 13        8.862510e+09  8.862510e+09             True       NaN        14
# 14        9.223065e+08  9.852395e+08            False       NaN        15
#
#     self_reported_circulating_supply  self_reported_market_cap tvl_ratio  \
# 0                                NaN                       NaN      None
# 1                                NaN                       NaN      None
# 2                                NaN                       NaN      None
# 3                                NaN                       NaN      None
# 4                                NaN                       NaN      None
# 5                       5.252369e+08              8.209014e+10      None
# 6                       6.090122e+10              6.088747e+10      None
# 7                       9.466789e+10              2.676272e+10      None
# 8                                NaN                       NaN      None
# 9                       3.799790e+10              1.991839e+10      None
# 10                      3.339317e+08              1.266912e+10      None
# 11                               NaN                       NaN      None
# 12                               NaN                       NaN      None
# 13                               NaN                       NaN      None
# 14                               NaN                       NaN      None
#
#                 last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0   2025-11-06T16:33:00.000Z    101482.458328          5.887003e+10
# 1   2025-11-06T16:33:00.000Z      3290.773774          3.626886e+10
# 2   2025-11-06T16:33:00.000Z         0.999411          1.310910e+11
# 3   2025-11-06T16:33:00.000Z         2.236729          5.812220e+09
# 4   2025-11-06T16:33:00.000Z       934.542611          2.808542e+09
# 5   2025-11-06T16:33:00.000Z       156.291646          5.714028e+09
# 6   2025-11-06T16:33:00.000Z         0.999774          1.714795e+10
# 7   2025-11-06T16:33:00.000Z         0.282701          6.172509e+08
# 8   2025-11-06T16:33:00.000Z         0.159221          1.829332e+09
# 9   2025-11-06T16:33:00.000Z         0.524197          8.868075e+08
# 10  2025-11-06T16:33:00.000Z        37.939264          4.780476e+08
# 11  2025-11-06T16:33:00.000Z        14.475229          7.768225e+08
# 12  2025-11-06T16:33:00.000Z       469.796300          2.677185e+08
# 13  2025-11-06T16:33:00.000Z         0.998846          2.265229e+08
# 14  2025-11-06T16:33:00.000Z         9.531232          8.821061e+05
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                      -45.0460                    -0.803791
# 1                      -48.9725                    -1.417150
# 2                      -42.2538                    -0.032684
# 3                      -37.4679                    -0.808775
# 4                      -48.5906                    -0.392398
# 5                      -46.2781                    -0.858689
# 6                      -41.0118                    -0.007586
# 7                      -51.9193                    -0.203850
# 8                      -56.7696                    -1.066844
# 9                      -49.6452                    -0.613297
# 10                     -52.2199                    -3.752309
# 11                     -44.7919                    -1.530429
# 12                     -31.0874                    -0.956851
# 13                     -42.9576                    -0.017099
# 14                      -8.1594                    -0.053416
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                      -2.021295                    -6.087237
# 1                      -3.005877                   -13.238423
# 2                      -0.103190                    -0.072605
# 3                      -1.234244                    -8.959922
# 4                      -2.578600                   -13.526898
# 5                      -1.895652                   -15.673701
# 6                      -0.059598                    -0.005709
# 7                      -1.569650                    -3.520959
# 8                      -4.377836                   -12.264587
# 9                      -3.874771                   -13.365910
# 10                     -8.503512                   -16.411171
# 11                     -3.754570                   -14.523059
# 12                     -3.923421                   -12.328007
# 13                     -0.037065                    -0.020138
# 14                      0.438708                    -0.879019
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                     -16.509893                     -8.749598
# 1                     -26.829057                    -23.294990
# 2                      -0.096449                     -0.071834
# 3                     -22.425475                    -22.357237
# 4                     -26.956313                      6.918675
# 5                     -30.123563                    -23.484400
# 6                       0.003841                     -0.018260
# 7                     -16.395827                    -14.160915
# 8                     -36.434951                    -28.444386
# 9                     -36.900766                    -36.899243
# 10                    -16.572803                    -20.122548
# 11                    -34.059597                    -35.099236
# 12                    -18.608393                    -21.910403
# 13                     -0.112602                     -0.183297
# 14                     -1.492525                     -0.133324
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                     -12.585039          2.024094e+12
# 1                     -16.979597          3.971871e+11
# 2                      -0.076550          1.833512e+11
# 3                     -30.946779          1.344435e+11
# 4                      18.954619          1.287216e+11
# 5                     -11.110075          8.638856e+10
# 6                      -0.024211          7.507423e+10
# 7                     -16.716500          2.676212e+10
# 8                     -28.210015          2.414776e+10
# 9                     -32.966354          1.880100e+10
# 10                     -5.970327          1.277359e+10
# 11                    -24.476323          1.008706e+10
# 12                    -18.995606          9.372107e+09
# 13                     -0.172751          8.852284e+09
# 14                      6.048896          8.790717e+09
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                          59.9783                        2.131132e+12
# 1                          11.7791                        3.971871e+11
# 2                           5.4375                        1.858417e+11
# 3                           3.9871                        2.236729e+11
# 4                           3.8143                        1.287216e+11
# 5                           2.5606                        9.587003e+10
# 6                           2.2252                        7.507423e+10
# 7                           0.7932                        2.676212e+10
# 8                           0.7157                        2.414776e+10
# 9                           0.5573                        2.358887e+10
# 10                          0.3788                        3.792156e+10
# 11                          0.2990                        1.447523e+10
# 12                          0.2777                        9.865722e+09
# 13                          0.2623                        8.852284e+09
# 14                          0.2605                        9.390546e+09
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2025-11-06T16:33:00.000Z          NaN           NaN
# 1           None  2025-11-06T16:33:00.000Z          NaN           NaN
# 2           None  2025-11-06T16:33:00.000Z       1027.0      Ethereum
# 3           None  2025-11-06T16:33:00.000Z          NaN           NaN
# 4           None  2025-11-06T16:33:00.000Z          NaN           NaN
# 5           None  2025-11-06T16:33:00.000Z          NaN           NaN
# 6           None  2025-11-06T16:33:00.000Z       1027.0      Ethereum
# 7           None  2025-11-06T16:33:00.000Z          NaN           NaN
# 8           None  2025-11-06T16:33:00.000Z          NaN           NaN
# 9           None  2025-11-06T16:33:00.000Z          NaN           NaN
# 10          None  2025-11-06T16:33:00.000Z      32196.0   Hyperliquid
# 11          None  2025-11-06T16:33:00.000Z       1027.0      Ethereum
# 12          None  2025-11-06T16:33:00.000Z          NaN           NaN
# 13          None  2025-11-06T16:33:00.000Z       1027.0      Ethereum
# 14          None  2025-11-06T16:33:00.000Z       1027.0      Ethereum
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              NaN           NaN                                         NaN
# 6              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10            HYPE   hyperliquid          0x0d01dc56dcaaca66ad901c959b4011ec
# 11             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 12             NaN           NaN                                         NaN
# 13             ETH      ethereum  0x4c9edd5852cd905f086c759e8383e09bff1e68b3
# 14             ETH      ethereum  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
#
#                     timestamp
# 0  2025-11-06 22:19:45.083022
# 1  2025-11-06 22:19:45.083022
# 2  2025-11-06 22:19:45.083022
# 3  2025-11-06 22:19:45.083022
# 4  2025-11-06 22:19:45.083022
# 5  2025-11-06 22:19:45.083022
# 6  2025-11-06 22:19:45.083022
# 7  2025-11-06 22:19:45.083022
# 8  2025-11-06 22:19:45.083022
# 9  2025-11-06 22:19:45.083022
# 10 2025-11-06 22:19:45.083022
# 11 2025-11-06 22:19:45.083022
# 12 2025-11-06 22:19:45.083022
# 13 2025-11-06 22:19:45.083022
# 14 2025-11-06 22:19:45.083022

# %%
# create automation  ( orginal we setup above and now append new (df2) here for automation )

def api_runner():
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'          # https://pro-api.coinmarketcap.com  (get this in Authenction part) 
    parameters = {
      'start':'1',
      'limit':'15',             # for ease you can set limit of data you want as (default set is 5000) 
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': 'abcdd7dd1d194f699a3d87d855c40015',  # insert your APi Key
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      # print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

    global df;

    #normalize and add timestamp 

    #  df2 = pd.json_normalize(data['data'])     # var[data]
    # df2['timestamp'] = pd.to_datetime('now')   # creating and adding timestamp column 
    # df = pd.concat([df, df2], ignore_index=True)    # appending df2 in df


    df = pd.json_normalize(data['data'])     # var[data]
    df['timestamp'] = pd.to_datetime('now')   # creating and adding timestamp column 
    df     # appending df2 in df

    if not os.path.isfile(r'C:\Python\Projects\automated files csv\Api.csv'):
        df.to_csv(r'C:\Python\Projects\automated files csv\Api.csv', header = 'column_names' )       # create csv and create header based on column name
    else:
        df.to_csv(r'C:\Python\Projects\automated files csv\Api.csv',mode = 'a',header =False  )

# %%
import os
from time import time
from time import sleep

 # this 333 is the time limit to use API per day so its max  (10000 per month)
for i in range(333):
    api_runner()
    print('Api runner completed successfully')    #joins the two DataFrames vertically (same as append).
    sleep(60)  # sleep for 1 minutes
exit()
# Out:
# Api runner completed successfully
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 9
#       7     api_runner()
#       8     print('Api runner completed successfully')    #joins the two DataFrames vertically (same as append).
# ----> 9     sleep(60)  # sleep for 1 minutes
#      10 exit()
#
# KeyboardInterrupt:

# %%
df_read = pd.read_csv(r"C:\Python\Projects\automated files csv\Api.csv")

df_read

# %% [markdown]
# ****Cleaning****

# %%
pd.set_option('display.float_format' , lambda x : '%.5f' %x)

# %%
df
# Out:
#        id          name symbol          slug  num_market_pairs  \
# 0       1       Bitcoin    BTC       bitcoin             12468
# 1    1027      Ethereum    ETH      ethereum             11100
# 2     825   Tether USDt   USDT        tether            157087
# 3      52           XRP    XRP           xrp              1754
# 4    1839           BNB    BNB           bnb              2934
# 5    5426        Solana    SOL        solana              1046
# 6    3408          USDC   USDC      usd-coin             34159
# 7    1958          TRON    TRX          tron              1259
# 8      74      Dogecoin   DOGE      dogecoin              1345
# 9    2010       Cardano    ADA       cardano              1621
# 10  32196   Hyperliquid   HYPE   hyperliquid               195
# 11   1975     Chainlink   LINK     chainlink              2143
# 12   1831  Bitcoin Cash    BCH  bitcoin-cash              1091
# 13  29470   Ethena USDe   USDe   ethena-usde               242
# 14   3957  UNUS SED LEO    LEO  unus-sed-leo                64
#
#                   date_added  \
# 0   2010-07-13T00:00:00.000Z
# 1   2015-08-07T00:00:00.000Z
# 2   2015-02-25T00:00:00.000Z
# 3   2013-08-04T00:00:00.000Z
# 4   2017-07-25T00:00:00.000Z
# 5   2020-04-10T00:00:00.000Z
# 6   2018-10-08T00:00:00.000Z
# 7   2017-09-13T00:00:00.000Z
# 8   2013-12-15T00:00:00.000Z
# 9   2017-10-01T00:00:00.000Z
# 10  2024-07-15T10:14:50.000Z
# 11  2017-09-20T00:00:00.000Z
# 12  2017-07-23T00:00:00.000Z
# 13  2024-02-20T11:05:01.000Z
# 14  2019-05-21T00:00:00.000Z
#
#                                                  tags         max_supply  \
# 0   [mineable, pow, sha-256, store-of-value, state...     21000000.00000
# 1   [pos, smart-contracts, ethereum-ecosystem, coi...                NaN
# 2   [stablecoin, asset-backed-stablecoin, usd-stab...                NaN
# 3   [medium-of-exchange, enterprise-solutions, xrp... 100000000000.00000
# 4   [marketplace, centralized-exchange, payments, ...    137737516.68000
# 5   [pos, platform, solana-ecosystem, cms-holdings...                NaN
# 6   [medium-of-exchange, stablecoin, asset-backed-...                NaN
# 7   [media, payments, tron-ecosystem, layer-1, dwf...                NaN
# 8   [mineable, pow, scrypt, medium-of-exchange, me...                NaN
# 9   [dpos, pos, platform, research, smart-contract...  45000000000.00000
# 10  [decentralized-exchange-dex-token, defi, deriv...    999533278.00000
# 11  [platform, cosmos-ecosystem, defi, interoperab...   1000000000.00000
# 12  [mineable, pow, sha-256, marketplace, medium-o...     21000000.00000
# 13  [stablecoin, asset-backed-stablecoin, binance-...                NaN
# 14  [marketplace, centralized-exchange, discount-t...                NaN
#
#     circulating_supply       total_supply  infinite_supply  platform  \
# 0       19945262.00000     19945262.00000            False       NaN
# 1      120697167.16149    120697167.16149             True       NaN
# 2   183459247850.01917 185951181472.87277             True       NaN
# 3    60107199237.00000  99985774127.00000            False       NaN
# 4      137737516.68000    137737516.68000            False       NaN
# 5      552739481.59230    613404685.40972             True       NaN
# 6    75091187792.37167  75091187792.37167            False       NaN
# 7    94665754479.34750  94665763485.71150             True       NaN
# 8   151662306383.70523 151662306383.70523             True       NaN
# 9    35866283823.40763  44994566647.19702            False       NaN
# 10     336685219.00000    999533278.00000            False       NaN
# 11     696849970.45259   1000000000.00000            False       NaN
# 12      19949300.00000     19949300.00000            False       NaN
# 13    8862509514.13945   8862509514.13945             True       NaN
# 14     922306473.90000    985239504.00000            False       NaN
#
#     cmc_rank  self_reported_circulating_supply  self_reported_market_cap  \
# 0          1                               NaN                       NaN
# 1          2                               NaN                       NaN
# 2          3                               NaN                       NaN
# 3          4                               NaN                       NaN
# 4          5                               NaN                       NaN
# 5          6                   525236893.30000         82090138826.77740
# 6          7                 60901219650.23000         60887465168.34230
# 7          8                 94667886298.42999         26762720629.60687
# 8          9                               NaN                       NaN
# 9         10                 37997904336.00000         19918388750.10302
# 10        11                   333931719.00000         12669123537.69763
# 11        12                               NaN                       NaN
# 12        13                               NaN                       NaN
# 13        14                               NaN                       NaN
# 14        15                               NaN                       NaN
#
#    tvl_ratio              last_updated  quote.USD.price  quote.USD.volume_24h  \
# 0       None  2025-11-06T16:33:00.000Z     101482.45833     58870031367.87058
# 1       None  2025-11-06T16:33:00.000Z       3290.77377     36268858819.21864
# 2       None  2025-11-06T16:33:00.000Z          0.99941    131091000929.60318
# 3       None  2025-11-06T16:33:00.000Z          2.23673      5812219545.47725
# 4       None  2025-11-06T16:33:00.000Z        934.54261      2808542253.26357
# 5       None  2025-11-06T16:33:00.000Z        156.29165      5714028200.13154
# 6       None  2025-11-06T16:33:00.000Z          0.99977     17147951648.46229
# 7       None  2025-11-06T16:33:00.000Z          0.28270       617250949.66109
# 8       None  2025-11-06T16:33:00.000Z          0.15922      1829332272.27765
# 9       None  2025-11-06T16:33:00.000Z          0.52420       886807523.48293
# 10      None  2025-11-06T16:33:00.000Z         37.93926       478047627.10794
# 11      None  2025-11-06T16:33:00.000Z         14.47523       776822479.37480
# 12      None  2025-11-06T16:33:00.000Z        469.79630       267718508.73437
# 13      None  2025-11-06T16:33:00.000Z          0.99885       226522893.56227
# 14      None  2025-11-06T16:33:00.000Z          9.53123          882106.14780
#
#     quote.USD.volume_change_24h  quote.USD.percent_change_1h  \
# 0                     -45.04600                     -0.80379
# 1                     -48.97250                     -1.41715
# 2                     -42.25380                     -0.03268
# 3                     -37.46790                     -0.80877
# 4                     -48.59060                     -0.39240
# 5                     -46.27810                     -0.85869
# 6                     -41.01180                     -0.00759
# 7                     -51.91930                     -0.20385
# 8                     -56.76960                     -1.06684
# 9                     -49.64520                     -0.61330
# 10                    -52.21990                     -3.75231
# 11                    -44.79190                     -1.53043
# 12                    -31.08740                     -0.95685
# 13                    -42.95760                     -0.01710
# 14                     -8.15940                     -0.05342
#
#     quote.USD.percent_change_24h  quote.USD.percent_change_7d  \
# 0                       -2.02129                     -6.08724
# 1                       -3.00588                    -13.23842
# 2                       -0.10319                     -0.07261
# 3                       -1.23424                     -8.95992
# 4                       -2.57860                    -13.52690
# 5                       -1.89565                    -15.67370
# 6                       -0.05960                     -0.00571
# 7                       -1.56965                     -3.52096
# 8                       -4.37784                    -12.26459
# 9                       -3.87477                    -13.36591
# 10                      -8.50351                    -16.41117
# 11                      -3.75457                    -14.52306
# 12                      -3.92342                    -12.32801
# 13                      -0.03707                     -0.02014
# 14                       0.43871                     -0.87902
#
#     quote.USD.percent_change_30d  quote.USD.percent_change_60d  \
# 0                      -16.50989                      -8.74960
# 1                      -26.82906                     -23.29499
# 2                       -0.09645                      -0.07183
# 3                      -22.42547                     -22.35724
# 4                      -26.95631                       6.91868
# 5                      -30.12356                     -23.48440
# 6                        0.00384                      -0.01826
# 7                      -16.39583                     -14.16091
# 8                      -36.43495                     -28.44439
# 9                      -36.90077                     -36.89924
# 10                     -16.57280                     -20.12255
# 11                     -34.05960                     -35.09924
# 12                     -18.60839                     -21.91040
# 13                      -0.11260                      -0.18330
# 14                      -1.49252                      -0.13332
#
#     quote.USD.percent_change_90d  quote.USD.market_cap  \
# 0                      -12.58504   2024094219762.91626
# 1                      -16.97960    397187072344.00110
# 2                       -0.07655    183351233318.85034
# 3                      -30.94678    134443529499.19069
# 4                       18.95462    128721578524.40143
# 5                      -11.11008     86388563632.44138
# 6                       -0.02421     75074228519.82593
# 7                      -16.71650     26762117961.89379
# 8                      -28.21001     24147764455.78418
# 9                      -32.96635     18800999599.84710
# 10                      -5.97033     12773589300.23590
# 11                     -24.47632     10087063172.04324
# 12                     -18.99561      9372107333.12009
# 13                      -0.17275      8852284034.58381
# 14                       6.04890      8790717038.09825
#
#     quote.USD.market_cap_dominance  quote.USD.fully_diluted_market_cap  \
# 0                         59.97830                 2131131624895.23999
# 1                         11.77910                  397187072344.00000
# 2                          5.43750                  185841699776.41000
# 3                          3.98710                  223672923053.84000
# 4                          3.81430                  128721578524.39999
# 5                          2.56060                   95870028218.89999
# 6                          2.22520                   75074228519.83000
# 7                          0.79320                   26762120508.00000
# 8                          0.71570                   24147764455.78000
# 9                          0.55730                   23588866528.76000
# 10                         0.37880                   37921556589.30000
# 11                         0.29900                   14475229389.03000
# 12                         0.27770                    9865722305.82000
# 13                         0.26230                    8852284034.58000
# 14                         0.26050                    9390546352.56000
#
#    quote.USD.tvl    quote.USD.last_updated  platform.id platform.name  \
# 0           None  2025-11-06T16:33:00.000Z          NaN           NaN
# 1           None  2025-11-06T16:33:00.000Z          NaN           NaN
# 2           None  2025-11-06T16:33:00.000Z   1027.00000      Ethereum
# 3           None  2025-11-06T16:33:00.000Z          NaN           NaN
# 4           None  2025-11-06T16:33:00.000Z          NaN           NaN
# 5           None  2025-11-06T16:33:00.000Z          NaN           NaN
# 6           None  2025-11-06T16:33:00.000Z   1027.00000      Ethereum
# 7           None  2025-11-06T16:33:00.000Z          NaN           NaN
# 8           None  2025-11-06T16:33:00.000Z          NaN           NaN
# 9           None  2025-11-06T16:33:00.000Z          NaN           NaN
# 10          None  2025-11-06T16:33:00.000Z  32196.00000   Hyperliquid
# 11          None  2025-11-06T16:33:00.000Z   1027.00000      Ethereum
# 12          None  2025-11-06T16:33:00.000Z          NaN           NaN
# 13          None  2025-11-06T16:33:00.000Z   1027.00000      Ethereum
# 14          None  2025-11-06T16:33:00.000Z   1027.00000      Ethereum
#
#    platform.symbol platform.slug                      platform.token_address  \
# 0              NaN           NaN                                         NaN
# 1              NaN           NaN                                         NaN
# 2              ETH      ethereum  0xdac17f958d2ee523a2206206994597c13d831ec7
# 3              NaN           NaN                                         NaN
# 4              NaN           NaN                                         NaN
# 5              NaN           NaN                                         NaN
# 6              ETH      ethereum  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
# 7              NaN           NaN                                         NaN
# 8              NaN           NaN                                         NaN
# 9              NaN           NaN                                         NaN
# 10            HYPE   hyperliquid          0x0d01dc56dcaaca66ad901c959b4011ec
# 11             ETH      ethereum  0x514910771af9ca656af840dff83e8264ecf986ca
# 12             NaN           NaN                                         NaN
# 13             ETH      ethereum  0x4c9edd5852cd905f086c759e8383e09bff1e68b3
# 14             ETH      ethereum  0x2af5d2ad76741191d15dfe7bf6ac92d4bd912ca3
#
#                     timestamp
# 0  2025-11-06 22:19:45.636648
# 1  2025-11-06 22:19:45.636648
# 2  2025-11-06 22:19:45.636648
# 3  2025-11-06 22:19:45.636648
# 4  2025-11-06 22:19:45.636648
# 5  2025-11-06 22:19:45.636648
# 6  2025-11-06 22:19:45.636648
# 7  2025-11-06 22:19:45.636648
# 8  2025-11-06 22:19:45.636648
# 9  2025-11-06 22:19:45.636648
# 10 2025-11-06 22:19:45.636648
# 11 2025-11-06 22:19:45.636648
# 12 2025-11-06 22:19:45.636648
# 13 2025-11-06 22:19:45.636648
# 14 2025-11-06 22:19:45.636648

# %%
df3 = df.groupby('name',sort=False)[['quote.USD.percent_change_1h' , 'quote.USD.percent_change_24h', 'quote.USD.percent_change_7d' ,'quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()

df3
# Out:
#               quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                          -0.80379                      -2.02129
# Ethereum                         -1.41715                      -3.00588
# Tether USDt                      -0.03268                      -0.10319
# XRP                              -0.80877                      -1.23424
# BNB                              -0.39240                      -2.57860
# Solana                           -0.85869                      -1.89565
# USDC                             -0.00759                      -0.05960
# TRON                             -0.20385                      -1.56965
# Dogecoin                         -1.06684                      -4.37784
# Cardano                          -0.61330                      -3.87477
# Hyperliquid                      -3.75231                      -8.50351
# Chainlink                        -1.53043                      -3.75457
# Bitcoin Cash                     -0.95685                      -3.92342
# Ethena USDe                      -0.01710                      -0.03707
# UNUS SED LEO                     -0.05342                       0.43871
#
#               quote.USD.percent_change_7d  quote.USD.percent_change_30d  \
# name
# Bitcoin                          -6.08724                     -16.50989
# Ethereum                        -13.23842                     -26.82906
# Tether USDt                      -0.07261                      -0.09645
# XRP                              -8.95992                     -22.42547
# BNB                             -13.52690                     -26.95631
# Solana                          -15.67370                     -30.12356
# USDC                             -0.00571                       0.00384
# TRON                             -3.52096                     -16.39583
# Dogecoin                        -12.26459                     -36.43495
# Cardano                         -13.36591                     -36.90077
# Hyperliquid                     -16.41117                     -16.57280
# Chainlink                       -14.52306                     -34.05960
# Bitcoin Cash                    -12.32801                     -18.60839
# Ethena USDe                      -0.02014                      -0.11260
# UNUS SED LEO                     -0.87902                      -1.49252
#
#               quote.USD.percent_change_60d  quote.USD.percent_change_90d
# name
# Bitcoin                           -8.74960                     -12.58504
# Ethereum                         -23.29499                     -16.97960
# Tether USDt                       -0.07183                      -0.07655
# XRP                              -22.35724                     -30.94678
# BNB                                6.91868                      18.95462
# Solana                           -23.48440                     -11.11008
# USDC                              -0.01826                      -0.02421
# TRON                             -14.16091                     -16.71650
# Dogecoin                         -28.44439                     -28.21001
# Cardano                          -36.89924                     -32.96635
# Hyperliquid                      -20.12255                      -5.97033
# Chainlink                        -35.09924                     -24.47632
# Bitcoin Cash                     -21.91040                     -18.99561
# Ethena USDe                       -0.18330                      -0.17275
# UNUS SED LEO                      -0.13332                       6.04890

# %%
df4 = df3.stack()

df4
# Out:
# name
# Bitcoin       quote.USD.percent_change_1h     -0.80379
#               quote.USD.percent_change_24h    -2.02129
#               quote.USD.percent_change_7d     -6.08724
#               quote.USD.percent_change_30d   -16.50989
#               quote.USD.percent_change_60d    -8.74960
#               quote.USD.percent_change_90d   -12.58504
# Ethereum      quote.USD.percent_change_1h     -1.41715
#               quote.USD.percent_change_24h    -3.00588
#               quote.USD.percent_change_7d    -13.23842
#               quote.USD.percent_change_30d   -26.82906
#               quote.USD.percent_change_60d   -23.29499
#               quote.USD.percent_change_90d   -16.97960
# Tether USDt   quote.USD.percent_change_1h     -0.03268
#               quote.USD.percent_change_24h    -0.10319
#               quote.USD.percent_change_7d     -0.07261
#               quote.USD.percent_change_30d    -0.09645
#               quote.USD.percent_change_60d    -0.07183
#               quote.USD.percent_change_90d    -0.07655
# XRP           quote.USD.percent_change_1h     -0.80877
#               quote.USD.percent_change_24h    -1.23424
#               quote.USD.percent_change_7d     -8.95992
#               quote.USD.percent_change_30d   -22.42547
#               quote.USD.percent_change_60d   -22.35724
#               quote.USD.percent_change_90d   -30.94678
# BNB           quote.USD.percent_change_1h     -0.39240
#               quote.USD.percent_change_24h    -2.57860
#               quote.USD.percent_change_7d    -13.52690
#               quote.USD.percent_change_30d   -26.95631
#               quote.USD.percent_change_60d     6.91868
#               quote.USD.percent_change_90d    18.95462
# Solana        quote.USD.percent_change_1h     -0.85869
#               quote.USD.percent_change_24h    -1.89565
#               quote.USD.percent_change_7d    -15.67370
#               quote.USD.percent_change_30d   -30.12356
#               quote.USD.percent_change_60d   -23.48440
#               quote.USD.percent_change_90d   -11.11008
# USDC          quote.USD.percent_change_1h     -0.00759
#               quote.USD.percent_change_24h    -0.05960
#               quote.USD.percent_change_7d     -0.00571
#               quote.USD.percent_change_30d     0.00384
#               quote.USD.percent_change_60d    -0.01826
#               quote.USD.percent_change_90d    -0.02421
# TRON          quote.USD.percent_change_1h     -0.20385
#               quote.USD.percent_change_24h    -1.56965
#               quote.USD.percent_change_7d     -3.52096
#               quote.USD.percent_change_30d   -16.39583
#               quote.USD.percent_change_60d   -14.16091
#               quote.USD.percent_change_90d   -16.71650
# Dogecoin      quote.USD.percent_change_1h     -1.06684
#               quote.USD.percent_change_24h    -4.37784
#               quote.USD.percent_change_7d    -12.26459
#               quote.USD.percent_change_30d   -36.43495
#               quote.USD.percent_change_60d   -28.44439
#               quote.USD.percent_change_90d   -28.21001
# Cardano       quote.USD.percent_change_1h     -0.61330
#               quote.USD.percent_change_24h    -3.87477
#               quote.USD.percent_change_7d    -13.36591
#               quote.USD.percent_change_30d   -36.90077
#               quote.USD.percent_change_60d   -36.89924
#               quote.USD.percent_change_90d   -32.96635
# Hyperliquid   quote.USD.percent_change_1h     -3.75231
#               quote.USD.percent_change_24h    -8.50351
#               quote.USD.percent_change_7d    -16.41117
#               quote.USD.percent_change_30d   -16.57280
#               quote.USD.percent_change_60d   -20.12255
#               quote.USD.percent_change_90d    -5.97033
# Chainlink     quote.USD.percent_change_1h     -1.53043
#               quote.USD.percent_change_24h    -3.75457
#               quote.USD.percent_change_7d    -14.52306
#               quote.USD.percent_change_30d   -34.05960
#               quote.USD.percent_change_60d   -35.09924
#               quote.USD.percent_change_90d   -24.47632
# Bitcoin Cash  quote.USD.percent_change_1h     -0.95685
#               quote.USD.percent_change_24h    -3.92342
#               quote.USD.percent_change_7d    -12.32801
#               quote.USD.percent_change_30d   -18.60839
#               quote.USD.percent_change_60d   -21.91040
#               quote.USD.percent_change_90d   -18.99561
# Ethena USDe   quote.USD.percent_change_1h     -0.01710
#               quote.USD.percent_change_24h    -0.03707
#               quote.USD.percent_change_7d     -0.02014
#               quote.USD.percent_change_30d    -0.11260
#               quote.USD.percent_change_60d    -0.18330
#               quote.USD.percent_change_90d    -0.17275
# UNUS SED LEO  quote.USD.percent_change_1h     -0.05342
#               quote.USD.percent_change_24h     0.43871
#               quote.USD.percent_change_7d     -0.87902
#               quote.USD.percent_change_30d    -1.49252
#               quote.USD.percent_change_60d    -0.13332
#               quote.USD.percent_change_90d     6.04890
# dtype: float64

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                              values
# name
# Bitcoin      quote.USD.percent_change_1h   -0.80379
#              quote.USD.percent_change_24h  -2.02129
#              quote.USD.percent_change_7d   -6.08724
#              quote.USD.percent_change_30d -16.50989
#              quote.USD.percent_change_60d  -8.74960
#              quote.USD.percent_change_90d -12.58504
# Ethereum     quote.USD.percent_change_1h   -1.41715
#              quote.USD.percent_change_24h  -3.00588
#              quote.USD.percent_change_7d  -13.23842
#              quote.USD.percent_change_30d -26.82906
#              quote.USD.percent_change_60d -23.29499
#              quote.USD.percent_change_90d -16.97960
# Tether USDt  quote.USD.percent_change_1h   -0.03268
#              quote.USD.percent_change_24h  -0.10319
#              quote.USD.percent_change_7d   -0.07261
#              quote.USD.percent_change_30d  -0.09645
#              quote.USD.percent_change_60d  -0.07183
#              quote.USD.percent_change_90d  -0.07655
# XRP          quote.USD.percent_change_1h   -0.80877
#              quote.USD.percent_change_24h  -1.23424
#              quote.USD.percent_change_7d   -8.95992
#              quote.USD.percent_change_30d -22.42547
#              quote.USD.percent_change_60d -22.35724
#              quote.USD.percent_change_90d -30.94678
# BNB          quote.USD.percent_change_1h   -0.39240
#              quote.USD.percent_change_24h  -2.57860
#              quote.USD.percent_change_7d  -13.52690
#              quote.USD.percent_change_30d -26.95631
#              quote.USD.percent_change_60d   6.91868
#              quote.USD.percent_change_90d  18.95462
# Solana       quote.USD.percent_change_1h   -0.85869
#              quote.USD.percent_change_24h  -1.89565
#              quote.USD.percent_change_7d  -15.67370
#              quote.USD.percent_change_30d -30.12356
#              quote.USD.percent_change_60d -23.48440
#              quote.USD.percent_change_90d -11.11008
# USDC         quote.USD.percent_change_1h   -0.00759
#              quote.USD.percent_change_24h  -0.05960
#              quote.USD.percent_change_7d   -0.00571
#              quote.USD.percent_change_30d   0.00384
#              quote.USD.percent_change_60d  -0.01826
#              quote.USD.percent_change_90d  -0.02421
# TRON         quote.USD.percent_change_1h   -0.20385
#              quote.USD.percent_change_24h  -1.56965
#              quote.USD.percent_change_7d   -3.52096
#              quote.USD.percent_change_30d -16.39583
#              quote.USD.percent_change_60d -14.16091
#              quote.USD.percent_change_90d -16.71650
# Dogecoin     quote.USD.percent_change_1h   -1.06684
#              quote.USD.percent_change_24h  -4.37784
#              quote.USD.percent_change_7d  -12.26459
#              quote.USD.percent_change_30d -36.43495
#              quote.USD.percent_change_60d -28.44439
#              quote.USD.percent_change_90d -28.21001
# Cardano      quote.USD.percent_change_1h   -0.61330
#              quote.USD.percent_change_24h  -3.87477
#              quote.USD.percent_change_7d  -13.36591
#              quote.USD.percent_change_30d -36.90077
#              quote.USD.percent_change_60d -36.89924
#              quote.USD.percent_change_90d -32.96635
# Hyperliquid  quote.USD.percent_change_1h   -3.75231
#              quote.USD.percent_change_24h  -8.50351
#              quote.USD.percent_change_7d  -16.41117
#              quote.USD.percent_change_30d -16.57280
#              quote.USD.percent_change_60d -20.12255
#              quote.USD.percent_change_90d  -5.97033
# Chainlink    quote.USD.percent_change_1h   -1.53043
#              quote.USD.percent_change_24h  -3.75457
#              quote.USD.percent_change_7d  -14.52306
#              quote.USD.percent_change_30d -34.05960
#              quote.USD.percent_change_60d -35.09924
#              quote.USD.percent_change_90d -24.47632
# Bitcoin Cash quote.USD.percent_change_1h   -0.95685
#              quote.USD.percent_change_24h  -3.92342
#              quote.USD.percent_change_7d  -12.32801
#              quote.USD.percent_change_30d -18.60839
#              quote.USD.percent_change_60d -21.91040
#              quote.USD.percent_change_90d -18.99561
# Ethena USDe  quote.USD.percent_change_1h   -0.01710
#              quote.USD.percent_change_24h  -0.03707
#              quote.USD.percent_change_7d   -0.02014
#              quote.USD.percent_change_30d  -0.11260
#              quote.USD.percent_change_60d  -0.18330
#              quote.USD.percent_change_90d  -0.17275
# UNUS SED LEO quote.USD.percent_change_1h   -0.05342
#              quote.USD.percent_change_24h   0.43871
#              quote.USD.percent_change_7d   -0.87902
#              quote.USD.percent_change_30d  -1.49252
#              quote.USD.percent_change_60d  -0.13332
#              quote.USD.percent_change_90d   6.04890

# %%
type(df5)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.index()
